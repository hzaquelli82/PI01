# %% [markdown]
# # Proceso ETL en archivo movies_datasets

# %% [markdown]
# Primero elimino las columnas que no se utilizarán en adelante, de acuerdo a la propuesta de trabajo.
# Para ello importo los datos y desde pandas elimino las columnas

# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('./datasets/movies_dataset.csv') #Cargamos los datos en un dataset
df.columns
# Out:
# /tmp/ipykernel_1921409/1336543721.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./datasets/movies_dataset.csv') #Cargamos los datos en un dataset
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Guardando columnas a eliminar en un dataframe aparte
columnas_eliminar = ['video','imdb_id','adult','original_title','poster_path','homepage']
df_trash = df[columnas_eliminar]
df_trash
# Out:
#        video    imdb_id  adult               original_title  \
# 0      False  tt0114709  False                    Toy Story
# 1      False  tt0113497  False                      Jumanji
# 2      False  tt0113228  False             Grumpier Old Men
# 3      False  tt0114885  False            Waiting to Exhale
# 4      False  tt0113041  False  Father of the Bride Part II
# ...      ...        ...    ...                          ...
# 45461  False  tt6209470  False                      رگ خواب
# 45462  False  tt2028550  False          Siglo ng Pagluluwal
# 45463  False  tt0303758  False                     Betrayal
# 45464  False  tt0008536  False          Satana likuyushchiy
# 45465  False  tt6980792  False                     Queerama
#
#                             poster_path                              homepage
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
# ...                                 ...                                   ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  http://www.imdb.com/title/tt6209470/
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg                                   NaN
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg                                   NaN
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg                                   NaN
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg                                   NaN
#
# [45466 rows x 6 columns]

# %% [markdown]
# Relizo primero esta eliminación para poder trabajar con menos datos y utilizar menos recursos de la máquina

# %%
# Eliminando columnas innecesarias del dataframe y almacenando en csv
df.drop(columnas_eliminar, axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   production_companies   45463 non-null  object
#  8   production_countries   45463 non-null  object
#  9   release_date           45379 non-null  object
#  10  revenue                45460 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
#  14  tagline                20412 non-null  object
#  15  title                  45460 non-null  object
#  16  vote_average           45460 non-null  float64
#  17  vote_count             45460 non-null  float64
# dtypes: float64(4), object(14)
# memory usage: 6.2+ MB

# %% [markdown]
# Relleno los valores vacíos de revenue y budget con 0.

# %%
df['revenue'] = df['revenue'].fillna(0)
df['budget'] = df['budget'].fillna(0)
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %% [markdown]
# Elimino las filas que no tienen fecha de estreno.

# %%
df.dropna(subset=['release_date'], inplace=True)
df.info()

#Ordeno el resultado para encontrar valores diferentes
df['release_date'].sort_values()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45379 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45379 non-null  object
#  2   genres                 45379 non-null  object
#  3   id                     45379 non-null  object
#  4   original_language      45368 non-null  object
#  5   overview               44438 non-null  object
#  6   popularity             45377 non-null  object
#  7   production_companies   45379 non-null  object
#  8   production_countries   45379 non-null  object
#  9   release_date           45379 non-null  object
#  10  revenue                45379 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
#  14  tagline                20398 non-null  object
#  15  title                  45376 non-null  object
#  16  vote_average           45376 non-null  float64
#  17  vote_count             45376 non-null  float64
# dtypes: float64(4), object(14)
# memory usage: 6.6+ MB
# 19730             1
# 29503            12
# 34940    1874-12-09
# 34937    1878-06-14
# 41602    1883-11-19
#             ...
# 38130    2018-04-25
# 30402    2018-11-07
# 38885    2018-12-31
# 26559    2020-12-16
# 35587            22
# Name: release_date, Length: 45379, dtype: object

# %% [markdown]
# Elimino valores de fechas atípicos

# %%
indices_eliminar = df[(df['release_date'] == '1') | (df['release_date'] == '12') | (df['release_date'] == '22')].index
print(indices_eliminar)
df.drop(indices_eliminar, inplace=True)
df.info()
df['release_date'].sort_values()
# Out:
# Index([19730, 29503, 35587], dtype='int64')
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget                 45376 non-null  object
#  2   genres                 45376 non-null  object
#  3   id                     45376 non-null  object
#  4   original_language      45365 non-null  object
#  5   overview               44435 non-null  object
#  6   popularity             45376 non-null  object
#  7   production_companies   45376 non-null  object
#  8   production_countries   45376 non-null  object
#  9   release_date           45376 non-null  object
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
#  14  tagline                20398 non-null  object
#  15  title                  45376 non-null  object
#  16  vote_average           45376 non-null  float64
#  17  vote_count             45376 non-null  float64
# dtypes: float64(4), object(14)
# memory usage: 6.6+ MB
# 34940    1874-12-09
# 34937    1878-06-14
# 41602    1883-11-19
# 34933    1887-08-18
# 34934    1888-01-01
#             ...
# 44535    2018-04-04
# 38130    2018-04-25
# 30402    2018-11-07
# 38885    2018-12-31
# 26559    2020-12-16
# Name: release_date, Length: 45376, dtype: object

# %% [markdown]
# Convierto release_date en formato fecha

# %%
df['release_date'] = pd.to_datetime(df['release_date'], format='%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget                 45376 non-null  object
#  2   genres                 45376 non-null  object
#  3   id                     45376 non-null  object
#  4   original_language      45365 non-null  object
#  5   overview               44435 non-null  object
#  6   popularity             45376 non-null  object
#  7   production_companies   45376 non-null  object
#  8   production_countries   45376 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
#  14  tagline                20398 non-null  object
#  15  title                  45376 non-null  object
#  16  vote_average           45376 non-null  float64
#  17  vote_count             45376 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(13)
# memory usage: 6.6+ MB

# %% [markdown]
# Creo la columna release_year

# %%
df['release_year'] = df['release_date'].dt.year

# %% [markdown]
# Creo una columna de mes para la función de contar filmaciones por mes

# %%
df['release_month'] = df['release_date'].dt.month
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget                 45376 non-null  object
#  2   genres                 45376 non-null  object
#  3   id                     45376 non-null  object
#  4   original_language      45365 non-null  object
#  5   overview               44435 non-null  object
#  6   popularity             45376 non-null  object
#  7   production_companies   45376 non-null  object
#  8   production_countries   45376 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
#  14  tagline                20398 non-null  object
#  15  title                  45376 non-null  object
#  16  vote_average           45376 non-null  float64
#  17  vote_count             45376 non-null  float64
#  18  release_year           45376 non-null  int32
#  19  release_month          45376 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(2), object(13)
# memory usage: 6.9+ MB

# %%
df.sample(5)
# Out:
#       belongs_to_collection budget  \
# 19380                   NaN      0
# 37544                   NaN      0
# 32228                   NaN      0
# 38647                   NaN      0
# 36610                   NaN      0
#
#                                                   genres      id  \
# 19380  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   35623
# 37544  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...  144436
# 32228  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...   60551
# 38647                      [{'id': 18, 'name': 'Drama'}]  226072
# 36610  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...   83903
#
#       original_language                                           overview  \
# 19380                he                                                NaN
# 37544                en  Porter's sequential continuity editing links s...
# 32228                en  A thrilling Cavalry-versus-Indians adventure s...
# 38647                hr  Mirjana is returning to Croatia from Germany w...
# 36610                hi  Aditya Singh, fondly called Adi Chachu by the ...
#
#       popularity                               production_companies  \
# 19380   0.375176  [{'name': 'Norddeutscher Rundfunk (NDR)', 'id'...
# 37544   0.205349  [{'name': 'Edison Manufacturing Company', 'id'...
# 32228   1.092612  [{'name': 'Universal International Pictures (U...
# 38647   0.078268  [{'name': 'Hrvatska Radiotelevizija (HRT)', 'i...
# 36610   0.352947  [{'name': 'Tips Music Films Pvt. Ltd.', 'id': ...
#
#                                     production_countries release_date  \
# 19380  [{'iso_3166_1': 'IL', 'name': 'Israel'}, {'iso...   2008-06-13
# 37544  [{'iso_3166_1': 'US', 'name': 'United States o...   1902-06-20
# 32228  [{'iso_3166_1': 'US', 'name': 'United States o...   1954-01-01
# 38647          [{'iso_3166_1': 'HR', 'name': 'Croatia'}]   2004-07-22
# 36610            [{'iso_3166_1': 'IN', 'name': 'India'}]   2005-12-23
#
#        revenue  runtime                                   spoken_languages  \
# 19380      0.0    100.0          [{'iso_639_1': 'he', 'name': 'עִבְרִית'}]
# 37544      0.0     10.0                                                 []
# 32228      0.0     78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 38647      0.0     70.0          [{'iso_639_1': 'hr', 'name': 'Hrvatski'}]
# 36610      0.0    132.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
#
#          status                                            tagline  \
# 19380  Released                                                NaN
# 37544  Released                                                NaN
# 32228  Released  Indian tomahawk and cavalry saber fighting sid...
# 38647  Released                                                NaN
# 36610  Released  Christmas is a time for friends and family and...
#
#                          title  vote_average  vote_count  release_year  \
# 19380            For My Father           6.1         8.0          2008
# 37544   Jack and the Beanstalk           5.9         4.0          1902
# 32228                War Arrow           6.4         6.0          1954
# 38647        Sorry for Kung Fu           4.5         2.0          2004
# 36610  Vaah! Life Ho Toh Aisi!           4.8         6.0          2005
#
#        release_month
# 19380              6
# 37544              6
# 32228              1
# 38647              7
# 36610             12

# %% [markdown]
# Para crear la columna return, primero cambio el tipo de dato de budget de int a float

# %%
df['budget'] = df['budget'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget                 45376 non-null  float64
#  2   genres                 45376 non-null  object
#  3   id                     45376 non-null  object
#  4   original_language      45365 non-null  object
#  5   overview               44435 non-null  object
#  6   popularity             45376 non-null  object
#  7   production_companies   45376 non-null  object
#  8   production_countries   45376 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
#  14  tagline                20398 non-null  object
#  15  title                  45376 non-null  object
#  16  vote_average           45376 non-null  float64
#  17  vote_count             45376 non-null  float64
#  18  release_year           45376 non-null  int32
#  19  release_month          45376 non-null  int32
# dtypes: datetime64[ns](1), float64(5), int32(2), object(12)
# memory usage: 6.9+ MB

# %% [markdown]
# Luego creo la columna return, a partir del cociente entre revenue y budget, uso para calcular la columna una función lambda

# %%
df['return'] = df.apply(lambda row: row['revenue'] / row['budget'] if row['budget'] != 0 else 0, axis=1)
df.head(5)
# Out:
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
#
#    runtime                                   spoken_languages    status  \
# 0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2    101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3    127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4    106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average  vote_count  release_year  \
# 0                    Toy Story          7.7      5415.0          1995
# 1                      Jumanji          6.9      2413.0          1995
# 2             Grumpier Old Men          6.5        92.0          1995
# 3            Waiting to Exhale          6.1        34.0          1995
# 4  Father of the Bride Part II          5.7       173.0          1995
#
#    release_month     return
# 0             10  12.451801
# 1             12   4.043035
# 2             12   0.000000
# 3             12   5.090760
# 4              2   0.000000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Normalizar

# %% [markdown]
# Empiezo con el proceso de desanidar columnas. Primero, mediante una función convertimos los datos tipo texto a diccionarios y listas según se traten.

# %%
def pre_desanidar (columna):
    '''Colocar como parámetro la columna de un dataframe para convertir str a dicc
    La función retornará un valor str como dicc o lista'''
    resultado = columna.apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else x)
    return resultado

# %%
df['belongs_to_collection'] = pre_desanidar(df['belongs_to_collection'])
df['genres'] = pre_desanidar(df['genres'])
df['production_companies'] = pre_desanidar(df['production_companies'])
df['production_countries'] = pre_desanidar(df['production_countries'])
df['spoken_languages'] = pre_desanidar(df['spoken_languages'])

df.sample(5)
# Out:
#       belongs_to_collection     budget  \
# 30173                   NaN  1100000.0
# 3405                    NaN        0.0
# 32094                   NaN        0.0
# 3445                    NaN        0.0
# 25724                   NaN        0.0
#
#                                                   genres      id  \
# 30173  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   39895
# 3405   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    1552
# 32094                     [{'id': 35, 'name': 'Comedy'}]   68275
# 3445   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   19600
# 25724                     [{'id': 35, 'name': 'Comedy'}]  283712
#
#       original_language                                           overview  \
# 30173                en  The uncle of an executed murderess relates fou...
# 3405                 en  The story of the Buckman family and friends, a...
# 32094                it  Forty-something Mattia has every woman in town...
# 3445                 en  Bossa Nova is a romantic comedy that enfolds m...
# 25724                en  Hot off the success of "Cars" and "Planes", a ...
#
#       popularity                               production_companies  \
# 30173   1.392022     [{'name': 'Conquest Productions', 'id': 6087}]
# 3405     8.09806  [{'name': 'Imagine Entertainment', 'id': 23}, ...
# 32094   1.581873                                                 []
# 3445    0.577044                                                 []
# 25724   0.104465                                                 []
#
#                                     production_countries release_date  ...  \
# 30173  [{'iso_3166_1': 'US', 'name': 'United States o...   1987-09-25  ...
# 3405   [{'iso_3166_1': 'US', 'name': 'United States o...   1989-07-31  ...
# 32094            [{'iso_3166_1': 'IT', 'name': 'Italy'}]   1983-12-22  ...
# 3445   [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2000-01-01  ...
# 25724                                                 []   2013-09-20  ...
#
#        runtime                                   spoken_languages    status  \
# 30173     99.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3405     124.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 32094     95.0          [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 3445      95.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 25724      6.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 30173  Welcome to Oldfield. Stop in for a night of pu...
# 3405   A comedy about life, love and the gentle art o...
# 32094                                                NaN
# 3445                                                 NaN
# 25724                             Get Ready to Set Sail!
#
#                             title vote_average  vote_count  release_year  \
# 30173  From a Whisper to a Scream          6.8        15.0          1987
# 3405                   Parenthood          6.4       177.0          1989
# 32094  Special Features: Handsome          5.9        16.0          1983
# 3445                   Bossa Nova          6.1         9.0          2000
# 25724                       Boats          3.5         2.0          2013
#
#        release_month    return
# 30173              9  1.272727
# 3405               7  0.000000
# 32094             12  0.000000
# 3445               1  0.000000
# 25724              9  0.000000
#
# [5 rows x 21 columns]

# %% [markdown]
# Para desanidar sigo el siguiente proceso: desanidar con la función json_normalize, y después extraer las columnas con datos útiles.

# %%
from pandas import json_normalize

df_normalizado = pd.json_normalize(df['belongs_to_collection'])
df['franchise'] = df_normalizado['name']
del df_normalizado
df.head()
# Out:
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  release_year  \
# 0                    Toy Story          7.7     5415.0          1995
# 1                      Jumanji          6.9     2413.0          1995
# 2             Grumpier Old Men          6.5       92.0          1995
# 3            Waiting to Exhale          6.1       34.0          1995
# 4  Father of the Bride Part II          5.7      173.0          1995
#
#    release_month     return                       franchise
# 0             10  12.451801            Toy Story Collection
# 1             12   4.043035                             NaN
# 2             12   0.000000       Grumpy Old Men Collection
# 3             12   5.090760                             NaN
# 4              2   0.000000  Father of the Bride Collection
#
# [5 rows x 22 columns]

# %% [markdown]
# Para las columnas que tengan lista de diccionarios, ejecuto una función lambda que extrae los valores útiles y los convierte en una lista nueva. Para ordenar el código, creo una función para llevar a cabo esta tarea.

# %%
def desanida_lista(df ,columna, name):
    """
    Esta función desanida una lista de diccionarios en una lista de valores, obtenidos de una 
    de las claves del diccionario.
    Y reemplaza la columna del df original
    
    Args:
        df (pandas.DataFrame): El dataframe original
        columna (str): nombre da la columna del df con listas de diccionario
        name (str): la clave de cada diccionario a conservar
    
    Returns:
        df (pandas.DataFrame): El dataframe con la columna desanida.
    """
    return df[columna].map(lambda x: [item[name].lower() for item in x])

# %%
df['genres'] = desanida_lista(df, 'genres', 'name')
df['production_companies'] = desanida_lista(df, 'production_companies', 'name')
df['production_countries'] = desanida_lista(df, 'production_countries', 'name')
df['spoken_languages'] = desanida_lista(df, 'spoken_languages', 'iso_639_1')
df.head()
# Out:
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                          genres     id original_language  \
# 0   [animation, comedy, family]    862                en
# 1  [adventure, fantasy, family]   8844                en
# 2             [romance, comedy]  15602                en
# 3      [comedy, drama, romance]  31357                en
# 4                      [comedy]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0                          [pixar animation studios]
# 1  [tristar pictures, teitler film, interscope co...
# 2                     [warner bros., lancaster gate]
# 3           [twentieth century fox film corporation]
# 4       [sandollar productions, touchstone pictures]
#
#          production_countries release_date  ...  spoken_languages    status  \
# 0  [united states of america]   1995-10-30  ...              [en]  Released
# 1  [united states of america]   1995-12-15  ...          [en, fr]  Released
# 2  [united states of america]   1995-12-22  ...              [en]  Released
# 3  [united states of america]   1995-12-22  ...              [en]  Released
# 4  [united states of america]   1995-02-10  ...              [en]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  release_year  \
# 0                    Toy Story          7.7     5415.0          1995
# 1                      Jumanji          6.9     2413.0          1995
# 2             Grumpier Old Men          6.5       92.0          1995
# 3            Waiting to Exhale          6.1       34.0          1995
# 4  Father of the Bride Part II          5.7      173.0          1995
#
#    release_month     return                       franchise
# 0             10  12.451801            Toy Story Collection
# 1             12   4.043035                             NaN
# 2             12   0.000000       Grumpy Old Men Collection
# 3             12   5.090760                             NaN
# 4              2   0.000000  Father of the Bride Collection
#
# [5 rows x 22 columns]

# %% [markdown]
# Elimino la columna original de 'belongs_of_collection'

# %%
df_trash['belongs_to_collection'] = df['belongs_to_collection']
df.drop('belongs_to_collection', axis=1, inplace=True)
df.head()
# Out:
# /tmp/ipykernel_1921409/2557370825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trash['belongs_to_collection'] = df['belongs_to_collection']
#        budget                        genres     id original_language  \
# 0  30000000.0   [animation, comedy, family]    862                en
# 1  65000000.0  [adventure, fantasy, family]   8844                en
# 2         0.0             [romance, comedy]  15602                en
# 3  16000000.0      [comedy, drama, romance]  31357                en
# 4         0.0                      [comedy]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0                          [pixar animation studios]
# 1  [tristar pictures, teitler film, interscope co...
# 2                     [warner bros., lancaster gate]
# 3           [twentieth century fox film corporation]
# 4       [sandollar productions, touchstone pictures]
#
#          production_countries release_date      revenue  ...  \
# 0  [united states of america]   1995-10-30  373554033.0  ...
# 1  [united states of america]   1995-12-15  262797249.0  ...
# 2  [united states of america]   1995-12-22          0.0  ...
# 3  [united states of america]   1995-12-22   81452156.0  ...
# 4  [united states of america]   1995-02-10   76578911.0  ...
#
#    spoken_languages    status  \
# 0              [en]  Released
# 1          [en, fr]  Released
# 2              [en]  Released
# 3              [en]  Released
# 4              [en]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average  vote_count  release_year  \
# 0                    Toy Story          7.7      5415.0          1995
# 1                      Jumanji          6.9      2413.0          1995
# 2             Grumpier Old Men          6.5        92.0          1995
# 3            Waiting to Exhale          6.1        34.0          1995
# 4  Father of the Bride Part II          5.7       173.0          1995
#
#    release_month     return                       franchise
# 0             10  12.451801            Toy Story Collection
# 1             12   4.043035                             NaN
# 2             12   0.000000       Grumpy Old Men Collection
# 3             12   5.090760                             NaN
# 4              2   0.000000  Father of the Bride Collection
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Otras transformaciones y limpiezas útiles

# %%
# Coloco los datos en lowercase para evitar el error en la busqueda por errar la mayuscula
df['title'] = df['title'].str.lower()

# %%
#Corregimos los valores de la columna 'popularity'
df['popularity'] = pd.to_numeric(df['popularity'])

# %% [markdown]
# Para la función filamciones_dia necesito conocer el día de la semana de cada estreno. Para ello uso la función strftime('%A') que devuelve el día de la semana de una fecha y creo una columna nueva para almacenar dicho dato.

# %%
df['release_day'] = df['release_date'].map(lambda x:  x.strftime('%A'))
df.head()
# Out:
#        budget                        genres     id original_language  \
# 0  30000000.0   [animation, comedy, family]    862                en
# 1  65000000.0  [adventure, fantasy, family]   8844                en
# 2         0.0             [romance, comedy]  15602                en
# 3  16000000.0      [comedy, drama, romance]  31357                en
# 4         0.0                      [comedy]  11862                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                                 production_companies  \
# 0                          [pixar animation studios]
# 1  [tristar pictures, teitler film, interscope co...
# 2                     [warner bros., lancaster gate]
# 3           [twentieth century fox film corporation]
# 4       [sandollar productions, touchstone pictures]
#
#          production_countries release_date      revenue  ...    status  \
# 0  [united states of america]   1995-10-30  373554033.0  ...  Released
# 1  [united states of america]   1995-12-15  262797249.0  ...  Released
# 2  [united states of america]   1995-12-22          0.0  ...  Released
# 3  [united states of america]   1995-12-22   81452156.0  ...  Released
# 4  [united states of america]   1995-02-10   76578911.0  ...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  release_year  \
# 0                    toy story          7.7     5415.0          1995
# 1                      jumanji          6.9     2413.0          1995
# 2             grumpier old men          6.5       92.0          1995
# 3            waiting to exhale          6.1       34.0          1995
# 4  father of the bride part ii          5.7      173.0          1995
#
#    release_month     return                       franchise  release_day
# 0             10  12.451801            Toy Story Collection       Monday
# 1             12   4.043035                             NaN       Friday
# 2             12   0.000000       Grumpy Old Men Collection       Friday
# 3             12   5.090760                             NaN       Friday
# 4              2   0.000000  Father of the Bride Collection       Friday
#
# [5 rows x 22 columns]

# %%
#Buscar títulos repetidos
title_counts = df['title'].value_counts()

title_counts[title_counts > 6]
# Out:
# title
# cinderella              11
# alice in wonderland      9
# hamlet                   9
# les misérables           8
# beauty and the beast     8
# a christmas carol        7
# blackout                 7
# the three musketeers     7
# treasure island          7
# Name: count, dtype: int64

# %% [markdown]
# # Proceso ETL en credits.csv

# %%
dfc = pd.read_csv('./datasets/credits.csv') #Carga de los datos en un dataframe
dfc.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# Convierto los strings en listas de diccionarios

# %%
dfc['cast'] = pre_desanidar(dfc['cast'])
dfc['crew'] = pre_desanidar(dfc['crew'])
dfc.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# Exporto el dataset en formato json porque me facilita la interpretación de la info

# %%
dfc.to_json('credits.json', orient='records', lines=True, indent=4)

# %%
dfc['actores'] =  desanida_lista(dfc, 'cast', 'name') #Creo la columna 'actores' conteniendo una lista de los actores de cada película
dfc.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                              actores
# 0  [tom hanks, tim allen, don rickles, jim varney...
# 1  [robin williams, jonathan hyde, kirsten dunst,...
# 2  [walter matthau, jack lemmon, ann-margret, sop...
# 3  [whitney houston, angela bassett, loretta devi...
# 4  [steve martin, diane keaton, martin short, kim...

# %% [markdown]
# Para extraer el director utilizo una función lambda que selecciona de la columna crew el valor de la clave 'name' del diccionario cuyo valor en la clave 'job' sea 'Director'
#
# A diferencia de la función lambda anterior, aqui usamos next para devolver el valor de 'name' y 'None' si no encuentra director. Esto para no generar una lista como resultado.

# %%
dfc['director'] = dfc['crew'].map(lambda x: next((crew['name'] for crew in x if crew['job'] == 'Director'), None))
dfc.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                              actores         director
# 0  [tom hanks, tim allen, don rickles, jim varney...    John Lasseter
# 1  [robin williams, jonathan hyde, kirsten dunst,...     Joe Johnston
# 2  [walter matthau, jack lemmon, ann-margret, sop...    Howard Deutch
# 3  [whitney houston, angela bassett, loretta devi...  Forest Whitaker
# 4  [steve martin, diane keaton, martin short, kim...    Charles Shyer

# %% [markdown]
# Elimino del df las columnas que ya no son necesarias

# %%
dfc.drop(['cast', 'crew'], axis=1, inplace=True)
dfc.head()
# Out:
#       id                                            actores         director
# 0    862  [tom hanks, tim allen, don rickles, jim varney...    John Lasseter
# 1   8844  [robin williams, jonathan hyde, kirsten dunst,...     Joe Johnston
# 2  15602  [walter matthau, jack lemmon, ann-margret, sop...    Howard Deutch
# 3  31357  [whitney houston, angela bassett, loretta devi...  Forest Whitaker
# 4  11862  [steve martin, diane keaton, martin short, kim...    Charles Shyer

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        45476 non-null  int64
#  1   actores   45476 non-null  object
#  2   director  44589 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# Creo un dataset con los nombres de los actores

# %%
actores = dfc['actores'].explode().unique()
actores =  pd.Series(actores).sort_values()
actores.to_csv('actores.csv')

# %% [markdown]
# ## Transformaciones Finales

# %%
#Convertir id en int64
df['id'] = df['id'].astype(int)
dfc['id'] = dfc['id'].astype(int)

# %%
df_final = pd.merge(df, dfc, on='id', how='left') #Uno los datasets a partir del id de la película
del df
df_final.head()
# Out:
#        budget                        genres     id original_language  \
# 0  30000000.0   [animation, comedy, family]    862                en
# 1  65000000.0  [adventure, fantasy, family]   8844                en
# 2         0.0             [romance, comedy]  15602                en
# 3  16000000.0      [comedy, drama, romance]  31357                en
# 4         0.0                      [comedy]  11862                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                                 production_companies  \
# 0                          [pixar animation studios]
# 1  [tristar pictures, teitler film, interscope co...
# 2                     [warner bros., lancaster gate]
# 3           [twentieth century fox film corporation]
# 4       [sandollar productions, touchstone pictures]
#
#          production_countries release_date      revenue  ...  \
# 0  [united states of america]   1995-10-30  373554033.0  ...
# 1  [united states of america]   1995-12-15  262797249.0  ...
# 2  [united states of america]   1995-12-22          0.0  ...
# 3  [united states of america]   1995-12-22   81452156.0  ...
# 4  [united states of america]   1995-02-10   76578911.0  ...
#
#                          title vote_average vote_count release_year  \
# 0                    toy story          7.7     5415.0         1995
# 1                      jumanji          6.9     2413.0         1995
# 2             grumpier old men          6.5       92.0         1995
# 3            waiting to exhale          6.1       34.0         1995
# 4  father of the bride part ii          5.7      173.0         1995
#
#   release_month     return                       franchise  release_day  \
# 0            10  12.451801            Toy Story Collection       Monday
# 1            12   4.043035                             NaN       Friday
# 2            12   0.000000       Grumpy Old Men Collection       Friday
# 3            12   5.090760                             NaN       Friday
# 4             2   0.000000  Father of the Bride Collection       Friday
#
#                                              actores         director
# 0  [tom hanks, tim allen, don rickles, jim varney...    John Lasseter
# 1  [robin williams, jonathan hyde, kirsten dunst,...     Joe Johnston
# 2  [walter matthau, jack lemmon, ann-margret, sop...    Howard Deutch
# 3  [whitney houston, angela bassett, loretta devi...  Forest Whitaker
# 4  [steve martin, diane keaton, martin short, kim...    Charles Shyer
#
# [5 rows x 24 columns]

# %%
df_final['director'] = df_final['director'].str.lower() #Convierto a minusculas el nombre de los directores
df_final['director']
# Out:
# 0           john lasseter
# 1            joe johnston
# 2           howard deutch
# 3         forest whitaker
# 4           charles shyer
#                ...
# 45447          john irvin
# 45448            lav diaz
# 45449      mark l. lester
# 45450    yakov protazanov
# 45451       daisy asquith
# Name: director, Length: 45452, dtype: object

# %%
actor = 'Will Smith'
peli_actor = dfc[dfc['actores'].map(lambda x: actor in x)]
peli_actor['id'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 0 entries
# Series name: id
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      int64
# dtypes: int64(1)
# memory usage: 0.0 bytes

# %% [markdown]
# ## Crear archivos necesarios para el proyecto

# %%
df_trash.to_csv('./datasets/columns_trash.csv')
del df_trash

# %%
df_final.to_parquet('movies_datasets.parquet',engine='pyarrow')

# %%
df_final.to_json('movies.json', orient='records', lines=True, indent=4)

# %%
del dfc

# %%
del df_final
